# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config3 import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
weatherpy_database_df = pd.read_csv(r'C:\Users\Nik\Bootcamp\06- WeatherPy API\World_Weather_Analysis\Module 6 Challenge\Weather_Database\WeatherPy_Database.csv')

# Display sample data
weatherpy_database_df.head()
# Out:
#    City_ID        City Country      lat       lng  Max Temp  Humidity  \
# 0        0       Vaini      TO -21.2000 -175.2000     77.16       100
# 1        1      Vostok      RU  46.4856  135.8833      7.25        93
# 2        2       Denia      ES  38.8408    0.1057     62.85        65
# 3        3     Corinto      GR  37.9407   22.9573     48.88        71
# 4        4  Chokurdakh      RU  70.6333  147.9167    -25.96        97
#
#    Cloudiness  Wind Speed Current Description
# 0          75        2.30       broken clouds
# 1          32        5.28    scattered clouds
# 2          98        1.99     overcast clouds
# 3          27        2.75    scattered clouds
# 4         100        3.60     overcast clouds

# %%
weatherpy_database_df.dtypes
# Out:
# City_ID                  int64
# City                    object
# Country                 object
# lat                    float64
# lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp= float(input("What's the minimum temperature you'd like on your vacation?"))
max_temp= float(input("What's the maximum temperature you'd like on your vacation?"))
# Out:
# What's the minimum temperature you'd like on your vacation?75
# What's the maximum temperature you'd like on your vacation?105

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = weatherpy_database_df.loc[
    (weatherpy_database_df["Max Temp"] <=max_temp) & (weatherpy_database_df['Max Temp'] >= min_temp)]

# Display sample data
preferred_cities_df.tail()
# Out:
#      City_ID          City Country      lat       lng  Max Temp  Humidity  \
# 645      645    Campoverde      PE  -8.4753  -74.8058     89.29        60
# 649      649      Tomatlan      MX  19.9333 -105.2500     89.82        25
# 651      651          Poum      NC -20.2333  164.0167     77.70        69
# 654      654      Goianira      BR -16.4961  -49.4264     80.42        83
# 660      660  Bull Savanna      JM  17.8868  -77.5902     78.30        66
#
#      Cloudiness  Wind Speed Current Description
# 645         100        1.63     overcast clouds
# 649           0        7.00           clear sky
# 651          24       10.74          few clouds
# 654          89        5.12          light rain
# 660          32        7.81    scattered clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_travel_cities = preferred_cities_df.dropna()

# Display sample data
clean_travel_cities.tail()
# Out:
#      City_ID          City Country      lat       lng  Max Temp  Humidity  \
# 645      645    Campoverde      PE  -8.4753  -74.8058     89.29        60
# 649      649      Tomatlan      MX  19.9333 -105.2500     89.82        25
# 651      651          Poum      NC -20.2333  164.0167     77.70        69
# 654      654      Goianira      BR -16.4961  -49.4264     80.42        83
# 660      660  Bull Savanna      JM  17.8868  -77.5902     78.30        66
#
#      Cloudiness  Wind Speed Current Description
# 645         100        1.63     overcast clouds
# 649           0        7.00           clear sky
# 651          24       10.74          few clouds
# 654          89        5.12          light rain
# 660          32        7.81    scattered clouds

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities[['City','Country','Max Temp', 'lat', 'lng', 'Current Description']].copy()
hotel_df.head(1)
# Out:
#     City Country  Max Temp   lat    lng Current Description
# 0  Vaini      TO     77.16 -21.2 -175.2       broken clouds

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel Name"]= ""

# Display sample data
hotel_df.head(5)
# Out:
#                City Country  Max Temp      lat       lng Current Description  \
# 0             Vaini      TO     77.16 -21.2000 -175.2000       broken clouds
# 12   Saint-Philippe      RE     78.39 -21.3585   55.7679          light rain
# 13         Altamira      BR     86.09  -3.2033  -52.2064       broken clouds
# 15           Cobija      BO     87.98 -11.0267  -68.7692       broken clouds
# 21  Bambous Virieux      MU     79.21 -20.3428   57.7575          light rain
#
#    Hotel Name
# 0
# 12
# 13
# 15
# 21

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {'categories':'accommodation.hotel', 'apiKey': geoapify_key, "limit":20}

# %% [markdown]
# # Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Print a message to follow up the hotel search
print("Starting hotel search")

#Iterate through the hotel_df dataframe
for index, row in hotel_df.iterrows():
    #Get latitude and longitude from DataFrame.
    latitude= row['lat']
    longitude= row['lng']
    
    #add the current city's lat and lng to the params dictionary
    params['filter'] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    #Set up the base URL for the geoapify places api
    base_url = "https://api.geoapify.com/v2/places" 
    
    #make request and retrieve the JSON data by using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    #Convert the API response to JSON format
    name_address= name_address.json()
    
    #get the first hotel from the results and store the name
    try:
        hotel_df.loc[index, 'Hotel Name'] = name_address['features'][0]['properties']['name']
    except(KeyError, IndexError):
        #if no hotel is found, set the hotel name as "no hotel found"
        hotel_df.loc[index, 'Hotel Name']= 'No hotel found'
       
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
    
# Display sample data        
hotel_df
# Out:
# Starting hotel search
# Vaini - nearest hotel: Keleti International Resort
# Saint-Philippe - nearest hotel: Le Baril
# Altamira - nearest hotel: Hotel Vale do Xingu
# Cobija - nearest hotel: Hotel El Cristo
# Bambous Virieux - nearest hotel: No hotel found
# Port Alfred - nearest hotel: No hotel found
# Pitimbu - nearest hotel: Pousada Brisa Mar
# Pochutla - nearest hotel: Posada San Jose
# Aguas Vermelhas - nearest hotel: No hotel found
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Dakar - nearest hotel: 翁记小吃
# San Policarpo - nearest hotel: No hotel found
# Puerto Ayora - nearest hotel: Hostal La Mirada De Solitario George
# Iracoubo - nearest hotel: No hotel found
# Atuona - nearest hotel: Pearl Resort
# Dzidzantun - nearest hotel: Hotel Hacienda San Francisco
# Bandarbeyla - nearest hotel: No hotel found
# Avarua - nearest hotel: Paradise Inn
# Panama City - nearest hotel: Hostal Familiar Carmencita
# Faanui - nearest hotel: Oa Oa Lodge
# Cabo San Lucas - nearest hotel: Comfort Rooms
# Nhulunbuy - nearest hotel: No hotel found
# Impfondo - nearest hotel: Tropicana
# Itarema - nearest hotel: Pousada Oásis
# Sao Felix Do Xingu - nearest hotel: Hotel Terraço
# Robertsport - nearest hotel: Nana's Lodge
# Arraial Do Cabo - nearest hotel: No hotel found
# Guane - nearest hotel: No hotel found
# Amapa - nearest hotel: No hotel found
# Palmas - nearest hotel: Hotel Triângulo Mineiro
# Hithadhoo - nearest hotel: Pebbles Inn
# Mahibadhoo - nearest hotel: Coral View Inn
# San Cristobal - nearest hotel: Terra Sur
# Maputo - nearest hotel: Mozaika
# Pisco - nearest hotel: La Portada
# Biak - nearest hotel: No hotel found
# Butaritari - nearest hotel: No hotel found
# Alta Floresta - nearest hotel: Villas Hotel
# Cayenne - nearest hotel: Central Hôtel
# Ewa Beach - nearest hotel: Hampton Inn & Suites Oahu/Kapolei
# Vila Velha - nearest hotel: Hotel Prainha
# Frontera - nearest hotel: Quirino
# Belmonte - nearest hotel: No hotel found
# Maraa - nearest hotel: No hotel found
# Georgetown - nearest hotel: Page 63 hostel
# Port Blair - nearest hotel: Andaman Ocean Breeze
# Saint-Georges - nearest hotel: Deyna's City Inn
# Mar Del Plata - nearest hotel: Nuevo Ostende
# Cidreira - nearest hotel: Hotel Castelo
# Kieta - nearest hotel: No hotel found
# Manyana - nearest hotel: No hotel found
# Maraba - nearest hotel: Portobelo
# Sao Filipe - nearest hotel: Bela Vista
# Acapulco - nearest hotel: Hotel del Valle
# Hilo - nearest hotel: Dolphin Bay Hotel
# Padang - nearest hotel: losmen Surya
# Banjar - nearest hotel: Villa Banjar Beach
# Iquitos - nearest hotel: Marfil del Amazonas
# San Lazaro - nearest hotel: No hotel found
# Kapoeta - nearest hotel: Kuleu
# Nosy Varika - nearest hotel: No hotel found
# Lorengau - nearest hotel: Seeadler Bay Hotel
# Cockburn Town - nearest hotel: The Salt Raker Inn
# Inirida - nearest hotel: Residencias El Turista del Guainia
# Soyo - nearest hotel: Hotel Maria Teres
# Meulaboh - nearest hotel: Hotel Meuligou
# Mbandaka - nearest hotel: Hôtel Epervier
# Tabou - nearest hotel: hôtel le rochet
# Manokwari - nearest hotel: Hotel Arfak
# Buchanan - nearest hotel: Phillipmena's Guesthouse
# Chuy - nearest hotel: Alerces
# Urubicha - nearest hotel: No hotel found
# Namatanai - nearest hotel: Namatanai Hotel
# Sao Joao Da Barra - nearest hotel: Pousada Mediterrâneo
# Mogadishu - nearest hotel: SYL Hotel
# Kilindoni - nearest hotel: Ibizza Inn
# Harper - nearest hotel: No hotel found
# Kismayo - nearest hotel: Kismayo Hotel
# Mazagao - nearest hotel: No hotel found
# Saint-Joseph - nearest hotel: No hotel found
# Yulara - nearest hotel: Outback Pioneer Hotel & Lodge
# Latung - nearest hotel: No hotel found
# Vallenar - nearest hotel: Hotel del Marqués
# Mana - nearest hotel: Le Samana
# Katherine - nearest hotel: No hotel found
# Rio Grande - nearest hotel: Hotel Vila Moura Executivo
# Pemangkat - nearest hotel: Hotel Kelapa Gading
# Broken Hill - nearest hotel: Ibis Styles
# Caravelas - nearest hotel: Pousada dos Navegantes
# Buala - nearest hotel: No hotel found
# Merauke - nearest hotel: No hotel found
# Salvador - nearest hotel: No hotel found
# Oranjestad - nearest hotel: Hotel California
# Souillac - nearest hotel: Hotel SkylineInn
# Buenaventura - nearest hotel: No hotel found
# Lakatoro - nearest hotel: No hotel found
# El Mante - nearest hotel: Hotel zaens
# Kailua - nearest hotel: No hotel found
# Eyl - nearest hotel: فندق ايل دابي
# Lazaro Cardenas - nearest hotel: Hotel Sol del Pacífico
# Axim - nearest hotel: Axim Beach Hotel
# Port Elizabeth - nearest hotel: Waterford Hotel
# Touros - nearest hotel: Pousada Atlântico
# Siocon - nearest hotel: No hotel found
# Coari - nearest hotel: Hotel Saúde
# Mahebourg - nearest hotel: Grand Bel Air
# Coroata - nearest hotel: No hotel found
# Puerto Lempira - nearest hotel: Hotel Samaritano
# Tayoltita - nearest hotel: No hotel found
# Alofi - nearest hotel: No hotel found
# Rivadavia - nearest hotel: Hotel Pasambay
# Nacozari - nearest hotel: No hotel found
# Tautira - nearest hotel: No hotel found
# Beboto - nearest hotel: No hotel found
# Charagua - nearest hotel: No hotel found
# Thinadhoo - nearest hotel: No hotel found
# Maues - nearest hotel: No hotel found
# Vung Tau - nearest hotel: No hotel found
# Dickinson - nearest hotel: Days Inn by Wyndham Dickinson TX
# Upington - nearest hotel: Die Eiland Holiday Ressort
# Arinos - nearest hotel: No hotel found
# Kununurra - nearest hotel: Kununurra Country Club Resort
# Kahului - nearest hotel: Maui Seaside Hotel
# Bubaque - nearest hotel: Chez Julio
# Salta - nearest hotel: Ayres de Salta Hotel
# Grand Gaube - nearest hotel: Coco Villa
# Dom Pedrito - nearest hotel: Hotel Alexandre
# Oriximina - nearest hotel: No hotel found
# Bonthe - nearest hotel: No hotel found
# Gurupi - nearest hotel: Via Norte
# Karratha - nearest hotel: Karratha International Hotel
# Makakilo City - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# Mumford - nearest hotel: No hotel found
# Corralillo - nearest hotel: No hotel found
# Azua - nearest hotel: Hotel Montemar
# Coahuayana - nearest hotel: No hotel found
# Vao - nearest hotel: Nataiwatch
# Samarai - nearest hotel: No hotel found
# Wukari - nearest hotel: No hotel found
# Contamana - nearest hotel: No hotel found
# Dzilam Gonzalez - nearest hotel: No hotel found
# Bouca - nearest hotel: No hotel found
# Barra Do Garcas - nearest hotel: Pousada Portal
# Xapuri - nearest hotel: Pousada Chapurys
# Pallavaram - nearest hotel: ML Residency
# Kavieng - nearest hotel: Kavieng Hotel
# Mananara - nearest hotel: Chez Roger
# Cosala - nearest hotel: Hotel Quinta Minera
# Dhidhdhoo - nearest hotel: No hotel found
# Neiafu - nearest hotel: Port Wine Guest House
# Quelimane - nearest hotel: Mabassa
# Fort Myers Beach - nearest hotel: Key Estero Shops
# Paciran - nearest hotel: No hotel found
# Abonnema - nearest hotel: No hotel found
# Manggar - nearest hotel: No hotel found
# San Rafael - nearest hotel: Hotel Regional
# Gamboma - nearest hotel: No hotel found
# Daru - nearest hotel: Kuki
# George Town - nearest hotel: Page 63 hostel
# Uaua - nearest hotel: Hotel Uauá
# Saltillo - nearest hotel: Hotel Colonial
# Ahuimanu - nearest hotel: No hotel found
# Labuhan - nearest hotel: No hotel found
# Dolores - nearest hotel: Plaza Hotel
# Bom Jesus - nearest hotel: Hotel Brasão
# Tarakan - nearest hotel: Hotel Dynasty
# Rocha - nearest hotel: Hotel Municipal
# Gigmoto - nearest hotel: No hotel found
# Alyangula - nearest hotel: No hotel found
# Lhokseumawe - nearest hotel: Vina Vira Hotel
# Mahajanga - nearest hotel: Vahiny Hotel
# Mayor Pablo Lagerenza - nearest hotel: No hotel found
# Gurupa - nearest hotel: No hotel found
# Port Hedland - nearest hotel: The Esplanade Hotel
# Auki - nearest hotel: No hotel found
# West Bay - nearest hotel: Bonnie's Arch
# Ambon - nearest hotel: Hotel Hero
# Praia - nearest hotel: Casa Sodadi
# Esmeraldas - nearest hotel: No hotel found
# Pimenta Bueno - nearest hotel: Cristalina palace hotel
# Sola - nearest hotel: No hotel found
# Fare - nearest hotel: hôtel Maitai Lapita Village
# Maningrida - nearest hotel: No hotel found
# Edgewater - nearest hotel: Best Western Edgewater Inn
# Sandakan - nearest hotel: Hotel City Star
# Calabozo - nearest hotel: Hotel Plaza Real
# Aitape - nearest hotel: No hotel found
# The Valley - nearest hotel: CeBlue
# Guaraniacu - nearest hotel: No hotel found
# Bougouni - nearest hotel: Hotel Piemont
# Campoverde - nearest hotel: No hotel found
# Tomatlan - nearest hotel: Hotel Hacienda Vieja Tomatlan
# Poum - nearest hotel: No hotel found
# Goianira - nearest hotel: No hotel found
# Bull Savanna - nearest hotel: Junction Guest House
#                 City Country  Max Temp      lat       lng Current Description  \
# 0              Vaini      TO     77.16 -21.2000 -175.2000       broken clouds
# 12    Saint-Philippe      RE     78.39 -21.3585   55.7679          light rain
# 13          Altamira      BR     86.09  -3.2033  -52.2064       broken clouds
# 15            Cobija      BO     87.98 -11.0267  -68.7692       broken clouds
# 21   Bambous Virieux      MU     79.21 -20.3428   57.7575          light rain
# ..               ...     ...       ...      ...       ...                 ...
# 645       Campoverde      PE     89.29  -8.4753  -74.8058     overcast clouds
# 649         Tomatlan      MX     89.82  19.9333 -105.2500           clear sky
# 651             Poum      NC     77.70 -20.2333  164.0167          few clouds
# 654         Goianira      BR     80.42 -16.4961  -49.4264          light rain
# 660     Bull Savanna      JM     78.30  17.8868  -77.5902    scattered clouds
#
#                         Hotel Name
# 0      Keleti International Resort
# 12                        Le Baril
# 13             Hotel Vale do Xingu
# 15                 Hotel El Cristo
# 21                  No hotel found
# ..                             ...
# 645                 No hotel found
# 649  Hotel Hacienda Vieja Tomatlan
# 651                 No hotel found
# 654                 No hotel found
# 660           Junction Guest House
#
# [195 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df= hotel_df[hotel_df['Hotel Name'].str.contains('No hotel found')==False]

# Display sample data
clean_hotel_df.sample(20)
# Out:
#                    City Country  Max Temp      lat       lng  \
# 372      Puerto Lempira      HN     79.27  15.2667  -83.7667
# 352              Touros      BR     82.96  -5.1989  -35.4608
# 184            Acapulco      MX     85.82  16.8634  -99.8901
# 190              Banjar      ID     76.37  -8.1900  114.9675
# 273              Yulara      AU     82.27 -25.2406  130.9889
# 92   Sao Felix Do Xingu      BR     82.76  -6.6447  -51.9950
# 37                Dakar      SN     85.08  14.6937  -17.4441
# 200             Iquitos      PE     80.64  -3.7481  -73.2472
# 557           Bom Jesus      BR     88.41  -9.0744  -44.3586
# 591            West Bay      KY     84.27  19.3667  -81.4167
# 257           Mogadishu      SO     77.70   2.0371   45.3438
# 463         Dom Pedrito      BR     97.03 -30.9828  -54.6731
# 540                Daru      PG     75.34  -9.0763  143.2092
# 185                Hilo      US     79.29  19.7297 -155.0900
# 344     Lazaro Cardenas      MX     82.35  17.9583 -102.2000
# 511            Mananara      MG     76.39 -16.1667   49.7667
# 592               Ambon      ID     75.34  -3.6954  128.1814
# 538          San Rafael      AR     82.76 -34.6177  -68.3301
# 623            Calabozo      VE     95.47   8.9242  -67.4293
# 347                Axim      GH     80.74   4.8699   -2.2405
#
#               Current Description                     Hotel Name
# 372                    light rain               Hotel Samaritano
# 352                     clear sky              Pousada Atlântico
# 184                     clear sky                Hotel del Valle
# 190               overcast clouds             Villa Banjar Beach
# 273                     clear sky  Outback Pioneer Hotel & Lodge
# 92                overcast clouds                  Hotel Terraço
# 37                      clear sky                           翁记小吃
# 200                 broken clouds            Marfil del Amazonas
# 557                 broken clouds                   Hotel Brasão
# 591                    few clouds                  Bonnie's Arch
# 257              scattered clouds                      SYL Hotel
# 463          heavy intensity rain                Hotel Alexandre
# 540               overcast clouds                           Kuki
# 185                     clear sky              Dolphin Bay Hotel
# 344                     clear sky         Hotel Sol del Pacífico
# 511                 moderate rain                     Chez Roger
# 592  thunderstorm with light rain                     Hotel Hero
# 538               overcast clouds                 Hotel Regional
# 623                    few clouds               Hotel Plaza Real
# 347                     clear sky               Axim Beach Hotel

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_file = 'WeatherPy_vacation.csv'

# Export the City_Data into a csv
clean_hotel_df.to_csv(output_file, index_label= 'City_ID')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6100\3266376194.py in <module>
#       3
#       4 # Export the City_Data into a csv
# ----> 5 clean_hotel_df.to_csv(output_file, index_label= 'City_ID')
#
# NameError: name 'clean_hotel_df' is not defined

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
#Configure the map
hotel_map= clean_hotel_df.hvplot.points('lng','lat', geo= True, tiles= 'OSM', frame_width=700,
                                 frame_height= 500, size= "Max Temp", scale=1, color= "City",
                                  hover_cols = ['Hotel Name', 'Country'])
# Display the map
hotel_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6100\2738427808.py in <module>
#       1 # Configure the map plot
#       2 #Configure the map
# ----> 3 hotel_map= clean_hotel_df.hvplot.points('lng','lat', geo= True, tiles= 'OSM', frame_width=700,
#       4                                  frame_height= 500, size= "Max Temp", scale=1, color= "City",
#       5                                   hover_cols = ['Hotel Name', 'Country'])
#
# NameError: name 'clean_hotel_df' is not defined
